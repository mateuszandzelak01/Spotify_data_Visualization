# %% [markdown]
# # Preparing Spotify Data for Tableau

# %%
import pandas as pd
import numpy as np
import requests

# %%
# read your 1+ StreamingHistory files (depending on how extensive your streaming history is) into pandas dataframes
df_stream = pd.read_json('StreamingHistory0.json')

# merge streaming dataframes if there is more than one json file
# df_stream = pd.concat([df_stream0, df_stream1])

# create a 'UniqueID' for each song by combining the fields 'artistName' and 'trackName'
df_stream['UniqueID'] = df_stream['artistName'] + ":" + df_stream['trackName']

df_stream.head()
# Out:
#             endTime   artistName                                trackName  \
# 0  2020-06-04 08:56  Major Lazer    Cold Water (feat. Justin Bieber & MØ)
# 1  2020-10-16 05:35       Tiësto                                 Acordeão
# 2  2020-10-16 05:35  Burak Yeter  My Life Is Going On - Burak Yeter Remix
# 3  2020-10-16 05:35         Parx                                  Fantasy
# 4  2020-10-16 05:35  Gorgon City                           Saving My Life
#
#    msPlayed                                           UniqueID
# 0     18820  Major Lazer:Cold Water (feat. Justin Bieber & MØ)
# 1    131204                                    Tiësto:Acordeão
# 2      4626  Burak Yeter:My Life Is Going On - Burak Yeter ...
# 3      1570                                       Parx:Fantasy
# 4      1168                         Gorgon City:Saving My Life

# %%
# read your edited Library json file into a pandas dataframe
df_library = pd.read_json('YourLibrary.json')

# %%
# add UniqueID column (same as above)
df_library['UniqueID'] = df_library['artist'] + ":" + df_library['track']

# add column with track URI stripped of 'spotify:track:'
new = df_library["uri"].str.split(":", expand = True)
df_library['track_uri'] = new[2]

df_library.head()
# Out:
#              artist                                              album  \
# 0  Paul Kalkbrenner  Berlin Calling (The Soundtrack by Paul Kalkbre...
# 1     One Direction                               Running Hits 2015.04
# 2            Miuosh                            MIUOSH | SMOLIK | NOSPR
# 3           The Six                               Running Hits 2015.04
# 4  Armin van Buuren                               Running Hits 2015.04
#
#                                           track  \
# 0                                           QSA
# 1                                  Drag Me Down
# 2                                      Perseidy
# 3  Unfinished Sympathy (feat. Jasmine Thompson)
# 4    Another You (feat. Mr. Probz) - Radio Edit
#
#                                     uri  \
# 0  spotify:track:3khntzHFE5TrhT7OKrFlPh
# 1  spotify:track:3AtYBAALKWcqxZs0KEKt4r
# 2  spotify:track:24kXwnMOucjqg4GAssQLks
# 3  spotify:track:2q8RkxBduttply1L2qF0rJ
# 4  spotify:track:57PlSDssRq1nXDqxNnfp7R
#
#                                             UniqueID               track_uri
# 0                               Paul Kalkbrenner:QSA  3khntzHFE5TrhT7OKrFlPh
# 1                         One Direction:Drag Me Down  3AtYBAALKWcqxZs0KEKt4r
# 2                                    Miuosh:Perseidy  24kXwnMOucjqg4GAssQLks
# 3  The Six:Unfinished Sympathy (feat. Jasmine Tho...  2q8RkxBduttply1L2qF0rJ
# 4  Armin van Buuren:Another You (feat. Mr. Probz)...  57PlSDssRq1nXDqxNnfp7R

# %%
# create final dict as a copy df_stream
df_powerbi = df_stream.copy()

# add column checking if streamed song is in library
# not used in this project but could be helpful for cool visualizations
df_powerbi['In Library'] = np.where(df_powerbi['UniqueID'].isin(df_library['UniqueID'].tolist()),1,0)

# left join with df_library on UniqueID to bring in album and track_uri
df_powerbi = pd.merge(df_powerbi, df_library[['album','UniqueID','track_uri']],how='left',on=['UniqueID'])

df_powerbi.head()
# Out:
#             endTime   artistName                                trackName  \
# 0  2020-06-04 08:56  Major Lazer    Cold Water (feat. Justin Bieber & MØ)
# 1  2020-10-16 05:35       Tiësto                                 Acordeão
# 2  2020-10-16 05:35  Burak Yeter  My Life Is Going On - Burak Yeter Remix
# 3  2020-10-16 05:35         Parx                                  Fantasy
# 4  2020-10-16 05:35  Gorgon City                           Saving My Life
#
#    msPlayed                                           UniqueID  In Library  \
# 0     18820  Major Lazer:Cold Water (feat. Justin Bieber & MØ)           0
# 1    131204                                    Tiësto:Acordeão           0
# 2      4626  Burak Yeter:My Life Is Going On - Burak Yeter ...           0
# 3      1570                                       Parx:Fantasy           0
# 4      1168                         Gorgon City:Saving My Life           0
#
#   album track_uri
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN
# 4   NaN       NaN

# %% [markdown]
# # Creating Genre Dataframe
